# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/datasets/ayaanaraza/eyetracking/Images'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS176_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS110_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS085_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS064_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS008_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS188_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS088_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS170_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS066_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS070_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS007_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS173_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS054_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS185_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS178_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS144_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS006_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS216_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS095_22.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS028_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS217_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS030_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS065_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS195_09.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS180_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS062_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS162_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS111_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS187_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS193_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS002_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS022_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS078_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS181_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS164_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS087_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS163_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS056_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS129_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS032_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS228_28.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS174_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS231_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS011_27.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS050_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS067_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS077_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS189_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS058_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS047_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS167_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS120_09.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS119_09.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS158_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS142_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS122_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS139_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS190_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS020_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS027_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS131_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS215_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS169_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS029_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS115_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS214_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS074_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS048_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS172_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS227_28.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS126_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS207_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS205_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS218_08.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS152_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS148_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS141_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS016_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS045_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS025_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS012_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS108_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS183_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS134_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS223_16.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS209_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS154_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS203_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS186_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS073_07.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS090_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS147_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS197_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS082_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS049_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS196_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS201_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS150_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS221_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS146_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS206_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS052_07.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS041_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS114_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS213_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS042_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS043_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS010_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS121_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS140_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS157_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS175_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS234_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS200_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS155_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS233_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS159_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS086_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS101_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS094_22.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS068_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS199_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS093_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS023_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS137_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS112_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS057_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS230_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS128_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS229_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS232_23.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS069_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS046_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS151_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS160_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS179_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS109_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS117_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS044_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS076_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS013_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS091_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS138_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS014_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS125_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS220_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS037_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS034_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS192_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS026_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS100_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS015_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS113_15.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS136_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS055_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS098_22.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS001_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS133_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS135_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS165_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS063_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS226_29.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS084_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS149_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS130_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS166_17.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS219_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS053_07.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS123_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS035_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS161_06.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS009_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS075_07.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS145_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS184_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS079_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS051_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS040_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS208_02.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS191_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS222_08.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS092_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS224_16.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS171_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS168_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS102_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS143_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS225_29.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS097_22.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS033_11.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS071_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS104_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS132_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS194_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS198_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS182_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS024_19.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS202_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS124_10.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS177_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS116_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS118_09.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS127_01.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS072_14.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS235_12.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS036_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS089_18.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS031_07.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS099_24.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS210_08.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS096_22.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS156_03.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS021_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS103_13.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS083_20.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS153_05.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS212_08.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS204_04.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages/TS211_08.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC179_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC040_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC233_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC275_56.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC058_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC019_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC193_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC339_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC018_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC221_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC306_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC196_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC314_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC224_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC037_31.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC289_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC274_56.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC059_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC086_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC116_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC045_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC072_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC189_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC292_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC007_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC032_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC265_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC344_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC049_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC305_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC217_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC202_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC250_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC311_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC352_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC188_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC143_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC285_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC171_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC308_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC219_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC210_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC329_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC115_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC124_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC146_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC130_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC220_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC288_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC341_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC102_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC335_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC138_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC127_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC100_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC266_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC328_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC114_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC152_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC064_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC163_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC153_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC104_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC043_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC129_55.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC061_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC244_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC263_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC296_46.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC302_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC333_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC319_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC218_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC190_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC079_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC255_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC330_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC307_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC343_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC182_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC322_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC145_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC176_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC251_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC154_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC150_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC069_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC312_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC194_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC270_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC106_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC271_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC053_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC267_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC160_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC048_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC334_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC178_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC047_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC071_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC142_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC331_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC067_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC060_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC126_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC290_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC119_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC186_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC073_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC248_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC205_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC123_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC199_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC273_56.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC327_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC323_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC029_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC004_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC223_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC080_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC321_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC057_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC324_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC227_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC282_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC256_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC075_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC325_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC096_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC077_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC105_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC125_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC198_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC157_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC158_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC280_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC028_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC101_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC098_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC082_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC054_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC349_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC034_31.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC121_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC297_46.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC021_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC175_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC235_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC164_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC026_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC108_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC192_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC216_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC083_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC269_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC038_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC228_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC039_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC162_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC291_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC131_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC002_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC159_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC206_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC076_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC132_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC044_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC298_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC278_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC081_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC294_46.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC237_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC315_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC332_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC133_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC183_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC174_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC137_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC234_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC148_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC279_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC036_31.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC268_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC254_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC184_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC309_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC207_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC027_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC113_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC030_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC173_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC253_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC084_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC035_31.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC252_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC151_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC172_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC020_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC180_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC304_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC117_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC232_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC318_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC208_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC167_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC317_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC066_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC342_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC141_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC231_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC166_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC055_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC276_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC135_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC320_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC144_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC065_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC087_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC161_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC169_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC236_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC204_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC052_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC203_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC050_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC225_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC272_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC056_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC085_51.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC295_46.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC226_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC316_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC200_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC022_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC197_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC287_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC070_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC170_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC299_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC168_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC187_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC246_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC097_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC155_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC041_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC042_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC348_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC245_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC243_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC031_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC024_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC345_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC257_59.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC088_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC109_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC046_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC139_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC006_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC118_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC068_43.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC016_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC310_44.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC017_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC010_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC103_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC149_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC230_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC136_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC283_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC305_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC033_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC247_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC008_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC005_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC063_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC025_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC023_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC338_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC326_38.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC051_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC120_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC128_55.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC062_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC111_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC099_54.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC156_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC089_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC336_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC351_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC209_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC112_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC201_49.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC074_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC134_36.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC122_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC350_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC281_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC185_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC337_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC181_34.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC003_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC264_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC340_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC110_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC090_47.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC277_53.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC222_50.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC147_35.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC301_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC177_30.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC313_45.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC284_32.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC001_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC346_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC286_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC347_58.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC249_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC293_46.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC107_39.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC165_37.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC195_52.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC303_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC009_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC140_40.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC300_33.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC229_57.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC191_48.png
# /kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages/TC078_52.png

# %%
import os
import glob
import numpy as np
import cv2
#from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from sklearn.decomposition import PCA

# %%
img_dim = 100
aug_img_count = 3
cropped_dir_tc= '/kaggle/working/Dataset/TC/Cropped'
cropped_dir_ts = '/kaggle/working/Dataset/TS/Cropped'
aug_tc_dir = '/kaggle/working/Dataset/TC/Augmented'
aug_ts_dir = '/kaggle/working/Dataset/TS/Augmented'
output_npz = '/kaggle/working/ASD_combined.npz'
os.makedirs(cropped_dir_tc, exist_ok=True)
os.makedirs(cropped_dir_ts, exist_ok=True)
os.makedirs(aug_tc_dir, exist_ok=True)
os.makedirs(aug_ts_dir, exist_ok=True)

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# ============ STEP 1: IMAGE AUGMENTATION ============
print("Starting full dataset augmentation...")

# Setup augmenter
augmenter = ImageDataGenerator(rotation_range=10, shear_range=0.2, zoom_range=0.2, fill_mode='nearest')

# Define original and augmented image directories
categories = {
    'TC': '/kaggle/input/datasets/ayaanaraza/eyetracking/Images/TCImages',
    'TS': '/kaggle/input/datasets/ayaanaraza/eyetracking/Images/TSImages'
}

# Update with your actual output folders for augmented images
aug_tc_dir = '/kaggle/working/Dataset/TC/Augmented'
aug_ts_dir = '/kaggle/working/Dataset/TS/Augmented'
os.makedirs(aug_tc_dir, exist_ok=True)
os.makedirs(aug_ts_dir, exist_ok=True)

# Number of augmented images to generate per original image
aug_img_count = 3

# Augment and save for all images
for category, folder in categories.items():
    save_dir = aug_tc_dir if category == 'TC' else aug_ts_dir
    image_paths = glob.glob(os.path.join(folder, '*.png'))
    print(f"\n Category: {category} | Original images: {len(image_paths)}")

    for file in image_paths:
        img = load_img(file)
        img_array = img_to_array(img)
        img_array = img_array.reshape((1,) + img_array.shape)
        base_name = os.path.splitext(os.path.basename(file))[0]
        count = 0
        for batch in augmenter.flow(img_array, batch_size=1, save_to_dir=save_dir,
                                   save_prefix=base_name + '_aug', save_format='png'):
            count += 1
            # Save the augmented images with the number appended
            if count == aug_img_count:
                break

    print(f" Augmented {aug_img_count * len(image_paths)} images saved to: {save_dir}")

# ============ STEP 2: SHOW ONE ORIGINAL + TWO AUGMENTED SAMPLES ============
print("\n Displaying 1 original + 2 augmented samples per category...")

preview_aug_count = 2  # Number of augmentations to preview

for category, folder in categories.items():
    image_paths = glob.glob(os.path.join(categories[category], '*.png'))
    if not image_paths:
        continue

    # Pick the first image
    img_path = image_paths[0]
    img = load_img(img_path)
    img_array = img_to_array(img).astype('uint8')
    img_array = img_array.reshape((1,) + img_array.shape)

    plt.figure(figsize=(10, 3))
    plt.subplot(1, preview_aug_count + 1, 1)
    plt.imshow(img_array[0].astype('uint8') / 255.0)
    plt.title("Original")
    plt.axis("off")

    for i, batch in enumerate(augmenter.flow(img_array, batch_size=1)):
        aug_img = batch[0].astype('uint8')
        # Add the augmentation number to the title
        plt.subplot(1, preview_aug_count + 1, i + 2)
        plt.imshow(aug_img / 255.0)
        plt.title(f'Aug {i+1}')
        plt.axis('off')
        if i + 1 == preview_aug_count:
            break

    plt.suptitle(f"{category} - Original + Augmented Samples", fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# Starting full dataset augmentation...
#
#  Category: TC | Original images: 328
#  Augmented 984 images saved to: /kaggle/working/Dataset/TC/Augmented
#
#  Category: TS | Original images: 219
#  Augmented 657 images saved to: /kaggle/working/Dataset/TS/Augmented
#
#  Displaying 1 original + 2 augmented samples per category...

# %%
aug_tc_images = glob.glob('/kaggle/working/Dataset/TC/Augmented/*.png')
aug_ts_images = glob.glob('/kaggle/working/Dataset/TS/Augmented/*.png')
print(f"TC Augmented: {len(aug_tc_images)} | TS: {len(aug_ts_images)}")
# Out:
# TC Augmented: 984 | TS: 657

# %%
aug_tc_images = glob.glob('/kaggle/working/Dataset/TC/Augmented/*.[Pp][Nn][Gg]')
aug_ts_images = glob.glob('/kaggle/working/Dataset/TS/Augmented/*.[Pp][Nn][Gg]')
print(f"TC Augmented: {len(aug_tc_images)} | TS: {len(aug_ts_images)}")

print("First 5 TC Augmented Images:", aug_tc_images[:5])
print("First 5 TS Augmented Images:", aug_ts_images[:5])
# Out:
# TC Augmented: 984 | TS: 657
# First 5 TC Augmented Images: ['/kaggle/working/Dataset/TC/Augmented/TC135_36_aug_0_8382.png', '/kaggle/working/Dataset/TC/Augmented/TC303_57_aug_0_8321.png', '/kaggle/working/Dataset/TC/Augmented/TC004_37_aug_0_6525.png', '/kaggle/working/Dataset/TC/Augmented/TC060_34_aug_0_2787.png', '/kaggle/working/Dataset/TC/Augmented/TC169_33_aug_0_3479.png']
# First 5 TS Augmented Images: ['/kaggle/working/Dataset/TS/Augmented/TS037_13_aug_0_6047.png', '/kaggle/working/Dataset/TS/Augmented/TS131_10_aug_0_3686.png', '/kaggle/working/Dataset/TS/Augmented/TS091_14_aug_0_4672.png', '/kaggle/working/Dataset/TS/Augmented/TS008_20_aug_0_3560.png', '/kaggle/working/Dataset/TS/Augmented/TS100_24_aug_0_9519.png']

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt

print(" Cropping augmented images and previewing...")

# Input folders
augmented_folders = [
    '/kaggle/working/Dataset/TC/Augmented',
    '/kaggle/working/Dataset/TS/Augmented'
]

# Output folders
cropped_dir_tc = '/kaggle/working/Dataset/TC/Cropped'
cropped_dir_ts = '/kaggle/working/Dataset/TS/Cropped'
os.makedirs(cropped_dir_tc, exist_ok=True)
os.makedirs(cropped_dir_ts, exist_ok=True)

# Counters and preview flags
tc_count = 0
ts_count = 0
tc_preview_shown = False
ts_preview_shown = False

# Process images
for folder in augmented_folders:
    for img_file in glob.iglob(os.path.join(folder, '**/*.png'), recursive=True):
        img = cv2.imread(img_file)
        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, threshed = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY)
        contours, _ = cv2.findContours(threshed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        if contours:
            cnt = max(contours, key=cv2.contourArea)
            x, y, w, h = cv2.boundingRect(cnt)
            cropped = img[y:y + h, x:x + w]
            resized = cv2.resize(cropped, (224, 224))

            # Decide category
            if 'TC' in folder:
                target_dir = cropped_dir_tc
                tc_count += 1
                preview_flag = not tc_preview_shown
                tc_preview_shown = True
            else:
                target_dir = cropped_dir_ts
                ts_count += 1
                preview_flag = not ts_preview_shown
                ts_preview_shown = True

            # Save
            img_id = os.path.basename(img_file).rsplit('.', 1)[0]
            save_path = os.path.join(target_dir, img_id + '.jpg')
            cv2.imwrite(save_path, resized, [int(cv2.IMWRITE_JPEG_QUALITY), 100])

            # Show one preview image per category
            if preview_flag:
                plt.figure(figsize=(6, 3))
                plt.subplot(1, 2, 1)
                plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
                plt.title("Original")
                plt.axis("off")

                plt.subplot(1, 2, 2)
                plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
                plt.title("Cropped & Resized")
                plt.axis("off")

                cat = 'TC' if 'TC' in folder else 'TS'
                plt.suptitle(f"{cat} Sample Image - Original vs Cropped", fontsize=14)
                plt.tight_layout()
                plt.show()

# Print final counts
print(f"\n Total Cropped Images:")
print(f"   TC: {tc_count}")
print(f"   TS: {ts_count}")
# Out:
#  Cropping augmented images and previewing...
#  Total Cropped Images:
#    TC: 984
#    TS: 657

# %%
aug_tc_images = glob.glob('/kaggle/working/Dataset/TC/Augmented/*.png')
crop_tc_images = glob.glob('/kaggle/working/Dataset/TC/Cropped/*.jpg')

print(f"TC Augmented: {len(aug_tc_images)} | TC Cropped: {len(crop_tc_images)}")

aug_ts_images = glob.glob('/kaggle/working/Dataset/TS/Augmented/*.png')
crop_ts_images = glob.glob('/kaggle/working/Dataset/TS/Cropped/*.jpg')

print(f"TC Augmented: {len(aug_ts_images)} | TC Cropped: {len(crop_ts_images)}")
# Out:
# TC Augmented: 984 | TC Cropped: 984
# TC Augmented: 657 | TC Cropped: 657

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/working'):
    if filenames:  # Only print folders that contain files
        print(dirname)
# Out:
# /kaggle/working/Dataset/TS/Augmented
# /kaggle/working/Dataset/TS/Cropped
# /kaggle/working/Dataset/TC/Augmented
# /kaggle/working/Dataset/TC/Cropped

# %% [markdown]
# ## MobileNet

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, AveragePooling2D,MaxPooling2D
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score
#from scipy import interp
import matplotlib.pyplot as plt
import time

# %%
import os
import glob
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.applications import MobileNet
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Step 1: Feature Extraction with MobileNet
print("Starting feature extraction using MobileNet...")

# MobileNet model setup
base_model = MobileNet(weights='imagenet', include_top=False, pooling='avg')
feature_extractor = Model(inputs=base_model.input, outputs=base_model.output)

# Directories
cropped_dirs = {
    'TC': '/kaggle/working/Dataset/TC/Cropped',
    'TS': '/kaggle/working/Dataset/TS/Cropped'
}

features = []
labels = []

# Extract features from each image
for label, (cat, folder) in enumerate(cropped_dirs.items()):
    print(f" Extracting features for category: {cat}")
    image_paths = glob.glob(os.path.join(folder, '*.jpg'))

    for img_path in tqdm(image_paths):
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)
        feature_vector = feature_extractor.predict(img_array, verbose=0)[0]
        features.append(feature_vector)
        labels.append(label)

# Convert to NumPy arrays
X = np.array(features)
y = np.array(labels)
print(f" Feature extraction complete! X shape: {X.shape}, y shape: {y.shape}")

# Step 2: Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)
# Out:
# Starting feature extraction using MobileNet...
# /tmp/ipykernel_31/759523091.py:21: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNet(weights='imagenet', include_top=False, pooling='avg')
# I0000 00:00:1745132085.874047      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#  Extracting features for category: TC
#   0%|          | 0/984 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745132091.252104      96 service.cc:148] XLA service 0x7ee4540033a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745132091.252685      96 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745132091.552797      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745132093.144531      96 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100%|██████████| 984/984 [01:03<00:00, 15.51it/s]
#  Extracting features for category: TS
# 100%|██████████| 657/657 [00:39<00:00, 16.44it/s]
#  Feature extraction complete! X shape: (1641, 1024), y shape: (1641,)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Use PCA to retain 99% of the variance
print("\n Applying PCA to retain 99% variance...")

pca = PCA(n_components=0.99, random_state=42)
X_reduced = pca.fit_transform(X)

print(f"Original shape: {X.shape}")
print(f"Reduced shape: {X_reduced.shape}")
print(f"Number of features selected: {X_reduced.shape[1]}")

# Step 2 (optional): Plot cumulative explained variance
plt.figure(figsize=(6, 4))
plt.plot(np.cumsum(pca.explained_variance_ratio_) * 100)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance (%)')
plt.title('PCA Variance Explained Curve')
plt.grid(True)
plt.axhline(y=95, color='r', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
#  Applying PCA to retain 99% variance...
# Original shape: (1641, 1024)
# Reduced shape: (1641, 569)
# Number of features selected: 569

# %%
# Step 2: Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# #No PCA DNN

# %%
# Step 3: Build and Train the Classification Model
print("\n Building and training classification model...")

classifier = Sequential([
    Dense(256, activation='relu', input_shape=(X.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # For binary classification: TC (0) vs TS (1)
])

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

history = classifier.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Step 4: Plot Accuracy and Loss
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Step 5: Evaluation
print("\n Classification Report:")
y_pred = (classifier.predict(X_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred, target_names=['TC', 'TS'], digits=5))

# Step 6: Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['TC', 'TS'], yticklabels=['TC', 'TS'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#  Building and training classification model...
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6285 - loss: 0.6690 - val_accuracy: 0.7599 - val_loss: 0.4859
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7443 - loss: 0.5083 - val_accuracy: 0.7812 - val_loss: 0.4388
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7658 - loss: 0.4873 - val_accuracy: 0.7903 - val_loss: 0.4211
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7802 - loss: 0.4441 - val_accuracy: 0.8207 - val_loss: 0.3981
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8351 - loss: 0.3525 - val_accuracy: 0.8298 - val_loss: 0.3578
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8499 - loss: 0.3326 - val_accuracy: 0.8419 - val_loss: 0.3478
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.2892 - val_accuracy: 0.8723 - val_loss: 0.2944
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8995 - loss: 0.2210 - val_accuracy: 0.8723 - val_loss: 0.2843
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9279 - loss: 0.1830 - val_accuracy: 0.8663 - val_loss: 0.3038
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.1690 - val_accuracy: 0.9149 - val_loss: 0.2217
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.1142 - val_accuracy: 0.9179 - val_loss: 0.1970
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1106 - val_accuracy: 0.9149 - val_loss: 0.1813
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9685 - loss: 0.1007 - val_accuracy: 0.8997 - val_loss: 0.2365
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.0855 - val_accuracy: 0.9210 - val_loss: 0.1983
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9716 - loss: 0.0799 - val_accuracy: 0.9149 - val_loss: 0.2212
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.0579 - val_accuracy: 0.9088 - val_loss: 0.2640
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9771 - loss: 0.0630 - val_accuracy: 0.9240 - val_loss: 0.1764
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9590 - loss: 0.1009 - val_accuracy: 0.9240 - val_loss: 0.1561
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.0646 - val_accuracy: 0.9362 - val_loss: 0.1745
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.0932 - val_accuracy: 0.9331 - val_loss: 0.1614
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9834 - loss: 0.0598 - val_accuracy: 0.9483 - val_loss: 0.1304
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0454 - val_accuracy: 0.9544 - val_loss: 0.1109
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0380 - val_accuracy: 0.9544 - val_loss: 0.1089
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0202 - val_accuracy: 0.9635 - val_loss: 0.0831
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0416 - val_accuracy: 0.9453 - val_loss: 0.1443
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0443 - val_accuracy: 0.9514 - val_loss: 0.1489
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0360 - val_accuracy: 0.9574 - val_loss: 0.1035
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0174 - val_accuracy: 0.9362 - val_loss: 0.2050
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.0563 - val_accuracy: 0.9544 - val_loss: 0.1035
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0181 - val_accuracy: 0.9544 - val_loss: 0.1257
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0155 - val_accuracy: 0.9483 - val_loss: 0.1427
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0379 - val_accuracy: 0.9453 - val_loss: 0.1332
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0371 - val_accuracy: 0.9514 - val_loss: 0.1267
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0357 - val_accuracy: 0.9422 - val_loss: 0.1475
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0456 - val_accuracy: 0.9514 - val_loss: 0.1443
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0336 - val_accuracy: 0.9514 - val_loss: 0.1504
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.0487 - val_accuracy: 0.9483 - val_loss: 0.1473
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0233 - val_accuracy: 0.9422 - val_loss: 0.1752
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0394 - val_accuracy: 0.9574 - val_loss: 0.1208
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0124 - val_accuracy: 0.9635 - val_loss: 0.1326
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0076 - val_accuracy: 0.9453 - val_loss: 0.1867
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0170 - val_accuracy: 0.9453 - val_loss: 0.1489
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9927 - loss: 0.0245 - val_accuracy: 0.9362 - val_loss: 0.2308
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.0424 - val_accuracy: 0.9483 - val_loss: 0.1545
#  Classification Report:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#           TC    0.96954   0.96954   0.96954       197
#           TS    0.95455   0.95455   0.95455       132
#
#     accuracy                        0.96353       329
#    macro avg    0.96204   0.96204   0.96204       329
# weighted avg    0.96353   0.96353   0.96353       329

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities (not hard labels)
y_pred_probs = classifier.predict(X_test)

# ROC Curve and AUC Score
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = roc_auc_score(y_test, y_pred_probs)

# Plot the ROC Curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for TC vs TS Classification')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# #PCA DNN

# %%
# Step 3: Build and Train the Classification Model
print("\n Building and training classification model with reduced features...")
X_train, X_test, y_train, y_test = train_test_split(
    X_reduced, y, test_size=0.2, stratify=y, random_state=42
)
classifier = Sequential([
    Dense(256, activation='relu', input_shape=(X_reduced.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # For binary classification: TC (0) vs TS (1)
])

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

history = classifier.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# Step 4: Plot Accuracy and Loss
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Step 5: Evaluation
print("\n Classification Report:")
y_pred = (classifier.predict(X_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred, target_names=['TC', 'TS'], digits=5))

# Step 6: Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['TC', 'TS'], yticklabels=['TC', 'TS'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#  Building and training classification model with reduced features...
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6530 - loss: 0.6144 - val_accuracy: 0.8116 - val_loss: 0.4039
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.3520 - val_accuracy: 0.8632 - val_loss: 0.2990
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.2113 - val_accuracy: 0.9027 - val_loss: 0.2112
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9678 - loss: 0.1031 - val_accuracy: 0.9483 - val_loss: 0.1383
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0422 - val_accuracy: 0.9514 - val_loss: 0.1264
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0203 - val_accuracy: 0.9514 - val_loss: 0.1232
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0125 - val_accuracy: 0.9514 - val_loss: 0.1089
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0083 - val_accuracy: 0.9574 - val_loss: 0.1083
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0128 - val_accuracy: 0.9605 - val_loss: 0.1132
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9635 - val_loss: 0.1124
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9605 - val_loss: 0.1202
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9574 - val_loss: 0.1193
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.9574 - val_loss: 0.1297
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 0.9605 - val_loss: 0.1493
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9514 - val_loss: 0.1614
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9544 - val_loss: 0.1656
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.3322e-04 - val_accuracy: 0.9483 - val_loss: 0.1669
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0027 - val_accuracy: 0.9483 - val_loss: 0.1771
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9574 - val_loss: 0.1749
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9574 - val_loss: 0.1792
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9483 - val_loss: 0.1895
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9514 - val_loss: 0.2050
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9544 - val_loss: 0.1986
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9544 - val_loss: 0.2037
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.9425e-04 - val_accuracy: 0.9574 - val_loss: 0.1994
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.3475e-04 - val_accuracy: 0.9605 - val_loss: 0.1979
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.1422e-04 - val_accuracy: 0.9605 - val_loss: 0.1965
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3590e-04 - val_accuracy: 0.9605 - val_loss: 0.1983
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.7355e-04 - val_accuracy: 0.9574 - val_loss: 0.1917
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.6721e-04 - val_accuracy: 0.9574 - val_loss: 0.1850
#  Classification Report:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#           TC    0.97436   0.96447   0.96939       197
#           TS    0.94776   0.96212   0.95489       132
#
#     accuracy                        0.96353       329
#    macro avg    0.96106   0.96329   0.96214       329
# weighted avg    0.96369   0.96353   0.96357       329

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities (not hard labels)
y_pred_probs = classifier.predict(X_test)

# ROC Curve and AUC Score
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = roc_auc_score(y_test, y_pred_probs)

# Plot the ROC Curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for TC vs TS Classification')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# #PCA ML

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import (
    RandomForestClassifier, AdaBoostClassifier,
    GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
)
from sklearn.metrics import (
    classification_report, accuracy_score,
    roc_auc_score, roc_curve
)
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# === ASSUME features and labels already loaded as X_features, y_labels ===

# Train/test split
#X_train, X_test, y_train, y_test = train_test_split(X_pca, y_labels, test_size=0.2, random_state=42)

# === MODELS ===
models = {
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "LightGBM": LGBMClassifier(random_state=42),
}

# Add a Voting Classifier (Ensemble)
models["Voting Ensemble"] = VotingClassifier(
    estimators=[
        ('rf', models["Random Forest"]),
        ('gb', models["Gradient Boosting"]),
        ('xgb', models["XGBoost"])
    ],
    voting='soft'
)

# === EVALUATION ===
plt.figure(figsize=(10, 8))
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    acc = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=["TC", "TS"])
    auc = roc_auc_score(y_test, y_prob)
    fpr, tpr, _ = roc_curve(y_test, y_prob)

    # Print performance
    print(f"\n Model: {name}")
    print(f"Accuracy: {acc:.4f}")
    print(f"ROC AUC: {auc:.4f}")
    print("Classification Report:")
    print(report)

    # Plot ROC
    plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.2f})")

# === ROC Curve Final Plot ===
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Boosting & Ensemble Models')
plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
#  Model: Random Forest
# Accuracy: 0.7903
# ROC AUC: 0.9250
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.74      0.99      0.85       197
#           TS       0.98      0.48      0.65       132
#
#     accuracy                           0.79       329
#    macro avg       0.86      0.74      0.75       329
# weighted avg       0.84      0.79      0.77       329
#
#
#  Model: Extra Trees
# Accuracy: 0.7447
# ROC AUC: 0.9416
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.70      0.99      0.82       197
#           TS       0.96      0.38      0.54       132
#
#     accuracy                           0.74       329
#    macro avg       0.83      0.68      0.68       329
# weighted avg       0.81      0.74      0.71       329
#
#
#  Model: AdaBoost
# Accuracy: 0.7964
# ROC AUC: 0.8702
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.80      0.87      0.84       197
#           TS       0.78      0.68      0.73       132
#
#     accuracy                           0.80       329
#    macro avg       0.79      0.78      0.78       329
# weighted avg       0.80      0.80      0.79       329
#
#
#  Model: Gradient Boosting
# Accuracy: 0.8815
# ROC AUC: 0.9442
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.87      0.95      0.91       197
#           TS       0.91      0.78      0.84       132
#
#     accuracy                           0.88       329
#    macro avg       0.89      0.86      0.87       329
# weighted avg       0.88      0.88      0.88       329
#
#
#  Model: XGBoost
# Accuracy: 0.8784
# ROC AUC: 0.9588
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.87      0.94      0.90       197
#           TS       0.90      0.78      0.84       132
#
#     accuracy                           0.88       329
#    macro avg       0.88      0.86      0.87       329
# weighted avg       0.88      0.88      0.88       329
#
# [LightGBM] [Info] Number of positive: 525, number of negative: 787
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 145095
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 569
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.400152 -> initscore=-0.404830
# [LightGBM] [Info] Start training from score -0.404830
#
#  Model: LightGBM
# Accuracy: 0.9058
# ROC AUC: 0.9721
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.88      0.97      0.92       197
#           TS       0.95      0.81      0.87       132
#
#     accuracy                           0.91       329
#    macro avg       0.92      0.89      0.90       329
# weighted avg       0.91      0.91      0.90       329
#
#
#  Model: Voting Ensemble
# Accuracy: 0.8784
# ROC AUC: 0.9616
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.86      0.95      0.90       197
#           TS       0.91      0.77      0.84       132
#
#     accuracy                           0.88       329
#    macro avg       0.89      0.86      0.87       329
# weighted avg       0.88      0.88      0.88       329

# %% [markdown]
# #No PCA ML

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import (
    RandomForestClassifier, AdaBoostClassifier,
    GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
)
from sklearn.metrics import (
    classification_report, accuracy_score,
    roc_auc_score, roc_curve
)
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier



# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# === MODELS ===
models = {
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "LightGBM": LGBMClassifier(random_state=42),
}

# Add a Voting Classifier (Ensemble)
models["Voting Ensemble"] = VotingClassifier(
    estimators=[
        ('rf', models["Random Forest"]),
        ('gb', models["Gradient Boosting"]),
        ('xgb', models["XGBoost"])
    ],
    voting='soft'
)

# === EVALUATION ===
plt.figure(figsize=(10, 8))
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    acc = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=["TC", "TS"])
    auc = roc_auc_score(y_test, y_prob)
    fpr, tpr, _ = roc_curve(y_test, y_prob)

    # Print performance
    print(f"\n Model: {name}")
    print(f"Accuracy: {acc:.4f}")
    print(f"ROC AUC: {auc:.4f}")
    print("Classification Report:")
    print(report)

    # Plot ROC
    plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.2f})")

# === ROC Curve Final Plot ===
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Boosting & Ensemble Models')
plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
#  Model: Random Forest
# Accuracy: 0.8784
# ROC AUC: 0.9576
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.86      0.95      0.90       197
#           TS       0.91      0.77      0.84       132
#
#     accuracy                           0.88       329
#    macro avg       0.89      0.86      0.87       329
# weighted avg       0.88      0.88      0.88       329
#
#
#  Model: Extra Trees
# Accuracy: 0.9119
# ROC AUC: 0.9738
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.89      0.98      0.93       197
#           TS       0.96      0.81      0.88       132
#
#     accuracy                           0.91       329
#    macro avg       0.92      0.90      0.91       329
# weighted avg       0.92      0.91      0.91       329
#
#
#  Model: AdaBoost
# Accuracy: 0.7872
# ROC AUC: 0.8863
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.83      0.81      0.82       197
#           TS       0.73      0.75      0.74       132
#
#     accuracy                           0.79       329
#    macro avg       0.78      0.78      0.78       329
# weighted avg       0.79      0.79      0.79       329
#
#
#  Model: Gradient Boosting
# Accuracy: 0.8754
# ROC AUC: 0.9427
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.88      0.92      0.90       197
#           TS       0.87      0.81      0.84       132
#
#     accuracy                           0.88       329
#    macro avg       0.87      0.86      0.87       329
# weighted avg       0.88      0.88      0.87       329
#
#
#  Model: XGBoost
# Accuracy: 0.9119
# ROC AUC: 0.9707
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.92      0.93      0.93       197
#           TS       0.90      0.88      0.89       132
#
#     accuracy                           0.91       329
#    macro avg       0.91      0.91      0.91       329
# weighted avg       0.91      0.91      0.91       329
#
# [LightGBM] [Info] Number of positive: 525, number of negative: 787
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 234091
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 1023
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.400152 -> initscore=-0.404830
# [LightGBM] [Info] Start training from score -0.404830
#
#  Model: LightGBM
# Accuracy: 0.9179
# ROC AUC: 0.9729
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.91      0.96      0.93       197
#           TS       0.93      0.86      0.89       132
#
#     accuracy                           0.92       329
#    macro avg       0.92      0.91      0.91       329
# weighted avg       0.92      0.92      0.92       329
#
#
#  Model: Voting Ensemble
# Accuracy: 0.9058
# ROC AUC: 0.9684
# Classification Report:
#               precision    recall  f1-score   support
#
#           TC       0.90      0.95      0.92       197
#           TS       0.92      0.84      0.88       132
#
#     accuracy                           0.91       329
#    macro avg       0.91      0.90      0.90       329
# weighted avg       0.91      0.91      0.91       329

# %% [markdown]
# ## Full MobileNet

# %%
import os, glob, numpy as np, cv2
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# %%
def load_images(folder, label):
    images, labels = [], []
    for path in glob.glob(os.path.join(folder, '*.jpg')):
        img = load_img(path, target_size=(224, 224))
        img = img_to_array(img)
        img = preprocess_input(img)
        images.append(img)
        labels.append(label)
    return images, labels

# Load from your cropped folders
tc_imgs, tc_labels = load_images('/kaggle/working/Dataset/TC/Cropped', 0)
ts_imgs, ts_labels = load_images('/kaggle/working/Dataset/TS/Cropped', 1)

X = np.array(tc_imgs + ts_imgs)
y = np.array(tc_labels + ts_labels)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# #Direct

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Load MobileNet base
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze early layers and fine-tune deeper layers
for layer in base_model.layers[:75]:  # Tune this number for your dataset size
    layer.trainable = False
for layer in base_model.layers[75:]:
    layer.trainable = True

# Add classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model with a moderate learning rate
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# E0000 00:00:1745134303.202078      95 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745134303.401305      95 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 14s 60ms/step - accuracy: 0.6238 - loss: 0.8041 - val_accuracy: 0.6322 - val_loss: 0.6971 - learning_rate: 1.0000e-04
# Epoch 2/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8590 - loss: 0.3279 - val_accuracy: 0.7842 - val_loss: 0.4454 - learning_rate: 1.0000e-04
# Epoch 3/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9312 - loss: 0.2226 - val_accuracy: 0.7538 - val_loss: 0.5269 - learning_rate: 1.0000e-04
# Epoch 4/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9604 - loss: 0.1294 - val_accuracy: 0.8936 - val_loss: 0.2640 - learning_rate: 1.0000e-04
# Epoch 5/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9739 - loss: 0.1020 - val_accuracy: 0.8967 - val_loss: 0.2405 - learning_rate: 1.0000e-04
# Epoch 6/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9916 - loss: 0.0615 - val_accuracy: 0.9119 - val_loss: 0.2025 - learning_rate: 1.0000e-04
# Epoch 7/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9845 - loss: 0.0546 - val_accuracy: 0.9271 - val_loss: 0.1873 - learning_rate: 1.0000e-04
# Epoch 8/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9909 - loss: 0.0488 - val_accuracy: 0.9392 - val_loss: 0.1780 - learning_rate: 1.0000e-04
# Epoch 9/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9962 - loss: 0.0369 - val_accuracy: 0.8875 - val_loss: 0.2453 - learning_rate: 1.0000e-04
# Epoch 10/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9961 - loss: 0.0358 - val_accuracy: 0.9422 - val_loss: 0.1776 - learning_rate: 1.0000e-04
# Epoch 11/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9970 - loss: 0.0268 - val_accuracy: 0.9422 - val_loss: 0.1538 - learning_rate: 1.0000e-04
# Epoch 12/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9948 - loss: 0.0244 - val_accuracy: 0.8997 - val_loss: 0.2694 - learning_rate: 1.0000e-04
# Epoch 13/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9991 - loss: 0.0136 - val_accuracy: 0.9483 - val_loss: 0.1621 - learning_rate: 1.0000e-04
# Epoch 14/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9968 - loss: 0.0290 - val_accuracy: 0.7933 - val_loss: 0.4948 - learning_rate: 1.0000e-04
# Epoch 15/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9949 - loss: 0.0201 - val_accuracy: 0.9453 - val_loss: 0.1842 - learning_rate: 1.0000e-04
# Epoch 16/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9895 - loss: 0.0303 - val_accuracy: 0.9514 - val_loss: 0.1434 - learning_rate: 1.0000e-04
# Epoch 17/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9972 - loss: 0.0199 - val_accuracy: 0.9422 - val_loss: 0.1435 - learning_rate: 1.0000e-04
# Epoch 18/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9913 - loss: 0.0250 - val_accuracy: 0.9422 - val_loss: 0.1669 - learning_rate: 1.0000e-04
# Epoch 19/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9977 - loss: 0.0147 - val_accuracy: 0.9271 - val_loss: 0.1878 - learning_rate: 1.0000e-04
# Epoch 20/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9994 - loss: 0.0109 - val_accuracy: 0.8967 - val_loss: 0.3169 - learning_rate: 1.0000e-04
# Epoch 21/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9997 - loss: 0.0108 - val_accuracy: 0.9331 - val_loss: 0.2383 - learning_rate: 1.0000e-04
# Epoch 22/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9088 - val_loss: 0.2989 - learning_rate: 1.0000e-04
# Epoch 23/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9976 - loss: 0.0111 - val_accuracy: 0.9392 - val_loss: 0.1506 - learning_rate: 1.0000e-04
# Epoch 24/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9998 - loss: 0.0076 - val_accuracy: 0.9392 - val_loss: 0.1647 - learning_rate: 1.0000e-04
# Epoch 25/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9991 - loss: 0.0062 - val_accuracy: 0.9392 - val_loss: 0.1910 - learning_rate: 1.0000e-04
# Epoch 26/100
# 79/82 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9900 - loss: 0.0231
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9903 - loss: 0.0225 - val_accuracy: 0.9422 - val_loss: 0.1438 - learning_rate: 1.0000e-04
# Epoch 27/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9982 - loss: 0.0078 - val_accuracy: 0.9544 - val_loss: 0.1386 - learning_rate: 5.0000e-05
# Epoch 28/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9963 - loss: 0.0076 - val_accuracy: 0.9483 - val_loss: 0.1264 - learning_rate: 5.0000e-05
# Epoch 29/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9514 - val_loss: 0.1416 - learning_rate: 5.0000e-05
# Epoch 30/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.9605 - val_loss: 0.1460 - learning_rate: 5.0000e-05
# Epoch 31/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9574 - val_loss: 0.1315 - learning_rate: 5.0000e-05
# Epoch 32/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9963 - loss: 0.0102 - val_accuracy: 0.9392 - val_loss: 0.1670 - learning_rate: 5.0000e-05
# Epoch 33/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9984 - loss: 0.0092 - val_accuracy: 0.8997 - val_loss: 0.3514 - learning_rate: 5.0000e-05
# Epoch 34/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9453 - val_loss: 0.1331 - learning_rate: 5.0000e-05
# Epoch 35/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9544 - val_loss: 0.1342 - learning_rate: 5.0000e-05
# Epoch 36/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9544 - val_loss: 0.1275 - learning_rate: 5.0000e-05
# Epoch 37/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9483 - val_loss: 0.1357 - learning_rate: 5.0000e-05
# Epoch 38/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9483 - val_loss: 0.1303 - learning_rate: 5.0000e-05
# Epoch 39/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9483 - val_loss: 0.1359 - learning_rate: 2.5000e-05
# Epoch 40/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9514 - val_loss: 0.1378 - learning_rate: 2.5000e-05
# Epoch 41/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9544 - val_loss: 0.1371 - learning_rate: 2.5000e-05
# Epoch 42/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9994 - loss: 0.0041 - val_accuracy: 0.9453 - val_loss: 0.1468 - learning_rate: 2.5000e-05
# Epoch 43/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9991 - loss: 0.0039 - val_accuracy: 0.9422 - val_loss: 0.1542 - learning_rate: 2.5000e-05
# Epoch 44/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9362 - val_loss: 0.1807 - learning_rate: 2.5000e-05
# Epoch 45/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9544 - val_loss: 0.1444 - learning_rate: 2.5000e-05
# Epoch 46/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9483 - val_loss: 0.1403 - learning_rate: 2.5000e-05
# Epoch 47/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9514 - val_loss: 0.1463 - learning_rate: 2.5000e-05
# Epoch 48/100
# 79/82 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9514 - val_loss: 0.1415 - learning_rate: 2.5000e-05
# Epoch 49/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 8.3277e-04 - val_accuracy: 0.9544 - val_loss: 0.1387 - learning_rate: 1.2500e-05
# Epoch 50/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9422 - val_loss: 0.1624 - learning_rate: 1.2500e-05
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title("Accuracy"); plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title("Loss"); plt.legend()
plt.tight_layout()
plt.show()

y_pred = (model.predict(X_test) > 0.5).astype('int32')
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=['TC', 'TS'], digits=5))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['TC', 'TS'], yticklabels=['TC', 'TS'])
plt.title("Confusion Matrix")
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#           TC    0.98421   0.94924   0.96641       197
#           TS    0.92806   0.97727   0.95203       132
#
#     accuracy                        0.96049       329
#    macro avg    0.95613   0.96326   0.95922       329
# weighted avg    0.96168   0.96049   0.96064       329

# %%
# Get predicted probabilities
y_pred_prob = model.predict(X_test).ravel()

# Compute ROC metrics
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Plot
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.4f})', color='darkorange', lw=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
import os, glob, numpy as np, cv2, random, tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# MobileNet-compatible Grad-CAM function
def make_gradcam_heatmap(img_array, model, last_conv_layer='conv_pw_13_relu'):
    grad_model = Model([model.inputs], [model.get_layer(last_conv_layer).output, model.output])
    with tf.GradientTape() as tape:
        conv_output, prediction = grad_model(img_array)
        loss = prediction[:, 0]
    grads = tape.gradient(loss, conv_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_output = conv_output[0].numpy()
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        conv_output[:, :, i] *= pooled_grads[i]
    heatmap = np.mean(conv_output, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap) + 1e-8
    return heatmap

# Display Grad-CAM for batch of cropped images
def display_gradcam_batch(X_data, y_data, model, num_samples=5, last_conv_layer='conv_pw_13_relu'):
    indices = random.sample(range(len(X_data)), num_samples)
    for idx in indices:
        img = X_data[idx]  # The cropped image
        label = y_data[idx]
        img_input = np.expand_dims(img, axis=0)

        # Generate Heatmap
        heatmap = make_gradcam_heatmap(img_input, model, last_conv_layer)

        # Convert back from [-1, 1] to [0, 255] for display (MobileNetV2 preprocessing)
        orig = img.copy()
        orig = orig[..., ::-1]  # BGR to RGB
        orig += [103.939, 116.779, 123.68]
        orig = np.clip(orig, 0, 255).astype('uint8')

        # Resize heatmap to match the cropped image size (which should already match the input size)
        heatmap_resized = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
        heatmap_vis = np.uint8(255 * heatmap_resized)
        overlay = cv2.applyColorMap(heatmap_vis, cv2.COLORMAP_JET)
        superimposed = cv2.addWeighted(np.uint8(orig), 0.6, overlay, 0.4, 0)

        # Make prediction
        pred = model.predict(img_input, verbose=0)[0][0]
        pred_class = 'TS' if pred >= 0.5 else 'TC'
        actual_class = 'TS' if label == 1 else 'TC'

        # Display the cropped image with heatmap overlay
        plt.figure(figsize=(12, 4))
        plt.suptitle(f"True: {actual_class} | Pred: {pred_class} ({pred:.2f})", fontsize=14)

        # Show the cropped image (input)
        plt.subplot(1, 3, 1)
        plt.imshow(orig)
        plt.title("Original Image")
        plt.axis('off')

        # Show the resized heatmap
        plt.subplot(1, 3, 2)
        plt.imshow(heatmap_resized, cmap='jet')
        plt.title("Heatmap")
        plt.axis('off')

        # Show the superimposed cropped image with heatmap overlay
        plt.subplot(1, 3, 3)
        plt.imshow(cv2.cvtColor(superimposed, cv2.COLOR_BGR2RGB))
        plt.title("Overlay on Cropped Image")
        plt.axis('off')

        plt.tight_layout()
        plt.show()

# Run Grad-CAM Visualization (make sure to define X_test, y_test, and model)
display_gradcam_batch(X_test, y_test, model, num_samples=5)
